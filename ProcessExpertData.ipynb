# %%
import os, random
import cv2
import math
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
meta_data = pd.read_csv(f"inputs\\train_metadata.csv")
meta_data.head()
# Out:
#   primary_label secondary_labels      type  latitude  longitude  \
# 0        asbfly               []  ['call']   39.2297   118.1987
# 1        asbfly               []  ['song']   51.4030   104.6401
# 2        asbfly               []  ['song']   36.3319   127.3555
# 3        asbfly               []  ['call']   21.1697    70.6005
# 4        asbfly               []  ['call']   15.5442    73.7733
#
#       scientific_name             common_name  \
# 0  Muscicapa dauurica  Asian Brown Flycatcher
# 1  Muscicapa dauurica  Asian Brown Flycatcher
# 2  Muscicapa dauurica  Asian Brown Flycatcher
# 3  Muscicapa dauurica  Asian Brown Flycatcher
# 4  Muscicapa dauurica  Asian Brown Flycatcher
#
#                               author  \
# 0                     Matt Slaymaker
# 1                   Magnus Hellström
# 2                      Stuart Fisher
# 3                          vir joshi
# 4  Albert Lastukhin & Sergei Karpeev
#
#                                              license  rating  \
# ...

# %%
meta_data = meta_data[["primary_label", "filename"]]

label_list = sorted(meta_data["primary_label"].unique())
label_id_list = list(range(len(label_list)))
label2id = dict(zip(label_list, label_id_list))
id2label = dict(zip(label_id_list, label_list))

# %%
def get_Ebird_list (df_path):
    '''
    Return set of EBird code in input annotation df dataset
    '''
    df_CCR = pd.read_csv(df_path)
    eBird = df_CCR["Species eBird Code"].unique()
    print(f"{df_path.split('/')[-2]} got {len(eBird)} eBird")
    return eBird

# %%
list_df_path = [
    "inputs/previous_dataset/ColumbiaAndCostaRica/annotations.csv",
    "inputs/previous_dataset/Hawaii/annotations.csv",
    "inputs/previous_dataset/SouthwesternAmazonBasin/annotations.csv",
    "inputs/previous_dataset/WesternUS/annotations.csv"
]

eBird_CCR = get_Ebird_list(list_df_path[0])
eBird_H = get_Ebird_list(list_df_path[1])
eBird_SAB = get_Ebird_list(list_df_path[2])
eBird_WUS = get_Ebird_list(list_df_path[3])
# Out:
# ColumbiaAndCostaRica got 90 eBird
# Hawaii got 27 eBird
# SouthwesternAmazonBasin got 133 eBird
# WesternUS got 56 eBird

# %%
print(list(set(eBird_CCR) & set(eBird_H) & set(eBird_SAB) & set(eBird_WUS)))
print(list(set(eBird_WUS) & set(label_list)))
# Out:
# []
# []

# %%
label_list
# Out:
# ['asbfly',
#  'ashdro1',
#  'ashpri1',
#  'ashwoo2',
#  'asikoe2',
#  'asiope1',
#  'aspfly1',
#  'aspswi1',
#  'barfly1',
#  'barswa',
#  'bcnher',
#  'bkcbul1',
#  'bkrfla1',
#  'bkskit1',
#  'bkwsti',
#  'bladro1',
#  'blaeag1',
#  'blakit1',
#  'blhori1',
#  'blnmon1',
#  'blrwar1',
#  'bncwoo3',
#  'brakit1',
#  'brasta1',
#  'brcful1',
#  'brfowl1',
#  'brnhao1',
#  'brnshr',
#  'brodro1',
#  'brwjac1',
#  'brwowl1',
#  'btbeat1',
#  'bwfshr1',
#  'categr',
#  'chbeat1',
#  'cohcuc1',
#  'comfla1',
#  'comgre',
#  'comior1',
#  'comkin1',
#  'commoo3',
#  'commyn',
#  'compea',
#  'comros',
#  'comsan',
#  'comtai1',
#  'copbar1',
#  'crbsun2',
#  'cregos1',
#  'crfbar1',
#  'crseag1',
#  'dafbab1',
#  'darter2',
#  'eaywag1',
#  'emedov2',
#  'eucdov',
#  'eurbla2',
#  'eurcoo',
#  'forwag1',
#  'gargan',
#  'gloibi',
#  'goflea1',
#  'graher1',
#  'grbeat1',
#  'grecou1',
#  'greegr',
#  'grefla1',
#  'grehor1',
#  'grejun2',
#  'grenig1',
#  'grewar3',
#  'grnsan',
# ...
